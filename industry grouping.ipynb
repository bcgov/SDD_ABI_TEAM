# %%
import pandas as pd
from spellchecker import SpellChecker
import re
spell = SpellChecker()
text_file = open("Downloads/stopwords.txt", "r")
stopwords = text_file.read().split('\n')
df = pd.read_csv('Downloads/spell_corrected_industry_counts.csv')
df.columns = ['Industry','count']

custom_stop = ["agency","animal","autobody","automobile","beverage","bpo","business","call","camp","canadian","car","center","centre","commercial","community","control","course","culture","customer","development","employed","employment","equipment","fire","firm","foods","glass","group","home","house","housing","human","immigration","industry","information","interior","keeping","living","local","long","maintenance","natural","non","none","office","organization","pet","private","processing","production","protection","real","safety","sands","save","sector","self","senior","service","services","social","support","temp","term","tire","trade","trades","trading","various","video","windows","work","worker","works"]

stopwords.extend(custom_stop)

df_new = df[df['Industry'].notnull()]
df_new['Processed'] = 'hello'

df_new['combined'] = False


print('a')
for index, row in df_new.iterrows():

    x = re.findall(r"[\w']+", row['Industry'])
    x = [spell.correction(w) for w in x]
    df_new.at[index, 'Processed'] = ' '.join(x)
top_entries = list(df_new.iloc[0:500,0])
print('finihsed')
# Out:
# a
# finihsed

# %%
df_new['new_count']=0
df_new['match'] = "NA"
df_new['association'] = "NA"
n=0
import warnings
warnings.filterwarnings('ignore')
for index, row in df_new.iloc[501:,].iterrows():
    n=n+1
    
    x = row['Processed'].split()
    x = [w for w in x if not w in stopwords]

    for xx in x:
        if row['combined'] == False:
            for tt in top_entries:
                t = tt.split()
                t = [w for w in t if not w in stopwords]

                for z in t:
                    if xx == z:
                        if row['combined'] == False:
                            
                            row['combined'] = True
                            df_new['new_count'][df_new.Industry == tt] = df_new['new_count'][df_new.Industry == tt] + row['count']
                            df_new['combined'][df_new.Industry == row['Industry']] = True
                            df_new['count'][df_new.Industry == row['Industry']] = 0
                            df_new['match'][df_new.Industry == row['Industry']] = xx
                            df_new['association'][df_new.Industry == row['Industry']] = tt
                            if n < 40:
                                print('we got a match')
                                print(n)
                                print(xx)
                                print(row)
                                print(df_new[df_new.Industry == z])
                                print(row['count'])
                                
print('finished')
# Out:
# we got a match
# 3
# travel
# Industry       travel & tourism
# count                         8
# Processed        travel tourism
# combined                   True
# new_count                     0
# match                        NA
# association                  NA
# Name: 503, dtype: object
#    Industry  count Processed  combined  new_count match association
# 59   travel     97    travel     False          8    NA          NA
# 8
# we got a match
# 5
# landscape
# Industry       landscape maintenance
# count                              8
# Processed      landscape maintenance
# combined                        True
# new_count                          0
# match                             NA
# association                       NA
# Name: 505, dtype: object
#       Industry  count  Processed  combined  new_count match association
# 192  landscape     25  landscape     False          8    NA          NA
# 8
# we got a match
# 8
# government
# Industry       provincial government
# count                              8
# Processed      provincial government
# combined                        True
# new_count                          0
# match                             NA
# association                       NA
# Name: 508, dtype: object
#       Industry  count   Processed  combined  new_count match association
# 47  government    137  government     False          8    NA          NA
# 8
# we got a match
# 9
# fishing
# Industry       fishing lodge
# count                      8
# Processed      fishing lodge
# combined                True
# new_count                  0
# match                     NA
# association               NA
# Name: 509, dtype: object
#    Industry  count Processed  combined  new_count match association
# 69  fishing     82   fishing     False          8    NA          NA
# 8
# we got a match
# 11
# tourism
# Industry       tourism/hospitality
# count                            8
# Processed      tourism hospitality
# combined                      True
# new_count                        0
# match                           NA
# association                     NA
# Name: 511, dtype: object
#    Industry  count Processed  combined  new_count match association
# 12  tourism    397   tourism     False          8    NA          NA
# 8
# we got a match
# 13
# construction
# Industry       construction/trades
# count                            8
# Processed      construction trades
# combined                      True
# new_count                        0
# match                           NA
# association                     NA
# Name: 513, dtype: object
#        Industry  count     Processed  combined  new_count match association
# 0  construction   3008  construction     False          8    NA          NA
# 8
# we got a match
# 14
# television
# Industry       television
# count                   8
# Processed      television
# combined             True
# new_count               0
# match                  NA
# association            NA
# Name: 514, dtype: object
#        Industry  count   Processed  combined  new_count       match  \
# 514  television      0  television      True          0  television
#
#              association
# 514  film and television
# 8
# we got a match
# 19
# store
# Industry       pet store
# count                  8
# Processed      pet store
# combined            True
# new_count              0
# match                 NA
# association           NA
# Name: 519, dtype: object
#     Industry  count Processed  combined  new_count match association
# 324    store     14     store     False          0    NA          NA
# 8
# we got a match
# 21
# dental
# Industry       dental office
# count                      8
# Processed      dental office
# combined                True
# new_count                  0
# match                     NA
# association               NA
# Name: 521, dtype: object
#    Industry  count Processed  combined  new_count match association
# 71   dental     80    dental     False          8    NA          NA
# 8
# we got a match
# 22
# retail
# Industry       outdoor retail
# count                       8
# Processed      outdoor retail
# combined                 True
# new_count                   0
# match                      NA
# association                NA
# Name: 522, dtype: object
#   Industry  count Processed  combined  new_count match association
# 1   retail   2154    retail     False          8    NA          NA
# 8
# we got a match
# 25
# public
# Industry       public transportation
# count                              8
# Processed      public transportation
# combined                        True
# new_count                          0
# match                             NA
# association                       NA
# Name: 525, dtype: object
#     Industry  count Processed  combined  new_count match association
# 856   public      4    public     False          0    NA          NA
# 8
# we got a match
# 26
# health
# Industry       natural health
# count                       8
# Processed      natural health
# combined                 True
# new_count                   0
# match                      NA
# association                NA
# Name: 526, dtype: object
#    Industry  count Processed  combined  new_count match association
# 13   health    390    health     False          0    NA          NA
# 8
# we got a match
# 31
# wood
# Industry       wood industry
# count                      8
# Processed      wood industry
# combined                True
# new_count                  0
# match                     NA
# association               NA
# Name: 531, dtype: object
#     Industry  count Processed  combined  new_count match association
# 194     wood     25      wood     False          8    NA          NA
# 8
# we got a match
# 32
# computer
# Industry       computer
# count                 8
# Processed      computer
# combined           True
# new_count             0
# match                NA
# association          NA
# Name: 532, dtype: object
#      Industry  count Processed  combined  new_count     match  \
# 532  computer      0  computer      True          0  computer
#
#            association
# 532  computer software
# 8
# we got a match
# 37
# dealership
# Industry       dealership
# count                   7
# Processed      dealership
# combined             True
# new_count               0
# match                  NA
# association            NA
# Name: 537, dtype: object
#        Industry  count   Processed  combined  new_count       match  \
# 537  dealership      0  dealership      True          0  dealership
#
#         association
# 537  car dealership
# 7
# finished

# %%
df_new.head()
df_new['total'] = df_new['count'] + df_new['new_count']
df_new.to_csv('Downloads/second_pass_at_industry_groupings_w_match_and_association.csv')

# %%
df_new['match'].value_counts().to_csv('Downloads/second_industry_matches_count.csv')
