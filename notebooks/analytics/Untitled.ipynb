# %%
import pandas as pd
    
import cx_Oracle

f=open("pwds.txt","r")
lines=f.readlines()
usr=lines[0]
pw=lines[1]
f.close()

host = ''
port = 1
service = ''
#cx_Oracle.init_oracle_client(lib_dir= path) # use this is service isn't initialised

cx_Oracle.clientversion()  
dsn_tns = cx_Oracle.makedsn(host, port, service_name=service)

conn = cx_Oracle.connect(user=usr, password=pw, dsn=dsn_tns)

c = conn.cursor()

query = """select "WBC_CASE_D"."CASE_NUM" "Case_Number", "WBC_DATE_D_Start"."CALENDAR_DATE" "Start_Date1", "WBC_ES_STAGE_OF_SERVICE_D"."STAGE_OF_SERVICE_NAME" "Stage_of_Employment_Service", avg("coguda30"."WEEKS_TO_SRVCPLAN_FIRST_EMP") "Weeks_to_First_Employment", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_EMPLOYED" "Accepted_Reason___Employed", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_PRECARIOUSLY_EMPLOYED" "c6", "WBC_LATEST_ES_OES_APP_D"."EXPLAINING_TO_OTHERS" "Explaining_to_Others", "WBC_LATEST_ES_OES_APP_D"."GET_ALONG_WITH_OTHERS" "Getting_Along_with_Others", "WBC_LATEST_ES_OES_APP_D"."LEARNING_NEW_THINGS" "New_Things", "WBC_LATEST_ES_OES_APP_D"."ORGANIZING_INFORMATION" "Organizing", "WBC_LATEST_ES_OES_APP_D"."PROBLEM_SOLVING" "Problem_Solving", "WBC_LATEST_ES_OES_APP_D"."READING_INFORMATION" "Reading_and_Understanding", "WBC_LATEST_ES_OES_APP_D"."USING_COMPUTERS" "Using_Computers", "WBC_LATEST_ES_OES_APP_D"."CREATING_DOCUMENTS" "Working_with_Documents", "WBC_LATEST_ES_OES_APP_D"."WORKING_WITH_MATH" "Working_with_Math", "WBC_LATEST_ES_OES_APP_D"."WRITING_INFORMATION" "Writing", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_EMPLOYER" "Employer_Name", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_JOB_TITLE" "Work_Title", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_INDUSTRY" "Industry", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_START_DATE" "Start_Date", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_END_DATE" "End_Date", "WBC_LATEST_ES_OES_APP_D"."REASON_FOR_LEAVING_EMPLOYMENT" "Reason_for_Leaving", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_SELF_EMPLOYED" "c23", "WBC_LATEST_ES_OES_APP_D"."MARITAL_STATUS" "Marital_Status", "WBC_LATEST_ES_OES_APP_D"."TOTAL_DEPENDENTS" "Number_of_Dependents", "WBC_LATEST_ES_OES_APP_D"."SCHOOL_LEVEL" "Education_Level", "WBC_LATEST_ES_OES_APP_D"."CURRENTLY_IN_SCHOOL" "Currently_In_School", "WBC_LATEST_ES_OES_APP_D"."CURRENTLY_IN_SCHOOL_STATUS" "c28", "WBC_LATEST_ES_OES_APP_D"."AREA_OF_STUDY" "Education_Area_of_Study", "WBC_LATEST_ES_OES_APP_D"."INDIGENOUS_TYPE" "Indigenous_Type", "WBC_LATEST_ES_OES_APP_D"."STATUS_INDIAN" "Status_Indian", "WBC_LATEST_ES_OES_APP_D"."IMMIGRATION_DATE" "Immigration_Date", "WBC_LATEST_ES_OES_APP_D"."REFUGEE_TYPE" "Refugee_Type", "WBC_LATEST_ES_OES_APP_D"."CITIZENSHIP_STATUS" "Citizenship_Status", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_AGE" "Age", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_LACK_HOUSING" "Lack_Housing", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_ADDICTION" "Addiction", "WBC_LATEST_ES_OES_APP_D"."VISIBLE_MINORITY" "Visible_Minority", "WBC_LATEST_ES_OES_APP_D"."CHILDREN_AT_HOME" "Child_at_Home", "WBC_LATEST_ES_OES_APP_D"."SINGLE_PARENT" "Single_Parent", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_PHYSICAL" "Physical_Disability", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_LEARNING" "Learning_Disability", "WBC_LATEST_ES_OES_APP_D"."DEVELOPMENTAL_DISABILITY" "Developmental_Disability", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_VISUAL" "Visual_Disability", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_HEARING" "Hearing_Disability", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_MENTAL_HEALTH" "Mental_Health_Condition", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_CHRONIC_ILLNESS" "Chronic_Illness", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_SHORT_TERM_ILLNESS" "Short_term_Illness", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_OTHER" "Other_Disability", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_LIST" "Employment_Factor_List", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_UNEMPLOYED" "Accepted_Reason___Unemployed", "WBC_LATEST_ES_OES_APP_D"."EMPLOYED" "Client_Employed_Flag", "WBC_LATEST_ES_OES_APP_D"."UNEMP_PERSONAL_SITUATION" "c53", "WBC_LATEST_ES_OES_APP_D"."UNEMP_KEEPING_JOBS" "Unemployed___Keeping_Jobs", "WBC_LATEST_ES_OES_APP_D"."UNEMP_DISABLTY_SUPPORTS_NEEDED" "c55", "WBC_LATEST_ES_OES_APP_D"."UNEMP_KIND_OF_WORK_UNKNOWN" "c56", "WBC_LATEST_ES_OES_APP_D"."UNEMP_FNCL_SUPPORTS_NEEDED" "c57", "WBC_LATEST_ES_OES_APP_D"."UNEMP_TRAINING_NEEDED" "Unemployed___Training_Needed", "WBC_LATEST_ES_OES_APP_D"."UNEMP_JOB_SEARCH_HELP_NEEDED" "c59", "WBC_LATEST_ES_OES_APP_D"."UNEMP_JOB_OFFER_LACK_RESOURCES" "Unemployed___Lack_Resources", "WBC_LATEST_ES_OES_APP_D"."UNEMP_RETURN_TO_SAME_WORK" "c61", "WBC_LATEST_ES_OES_APP_D"."UNEMP_OTHER_FACTOR" "Unemployed___Other", "WBC_LATEST_ES_OES_APP_D"."EMP_SELF_EMPLOYED" "Employed___Self_Employed", "WBC_LATEST_ES_OES_APP_D"."EMP_LOSING_JOB" "Employed___Losing_Job", "WBC_LATEST_ES_OES_APP_D"."EMP_DISABLTY_SUPPORTS_NEEDED" "Employed___Disability_Supports", "WBC_LATEST_ES_OES_APP_D"."EMP_JOB_OFFER_LACK_RESOURCES" "Employed___Lack_Resources", "WBC_LATEST_ES_OES_APP_D"."EMP_NEED_MORE_HOURS_OF_WORK" "Employed___Need_More_hours", "WBC_LATEST_ES_OES_APP_D"."EMP_TRAINING_NEEDED" "Employed___Training", "WBC_LATEST_ES_OES_APP_D"."EMP_NEW_LINE_OF_WORK" "Employed___New_Line_of_Work", "WBC_LATEST_ES_OES_APP_D"."EMP_SEEKEING_CHANGE" "Employed___Dislike_Current", "WBC_LATEST_ES_OES_APP_D"."EMP_CHALLENGING_JOB" "Employed___More_Challenge", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_OTHER" "Employed___Other", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_SITUATION_LIST" "Employment_Situation_List", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_NOT_IN_LABOUR_FORCE" "c74", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_IN_PERSON" "Interview_In_Person", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_PHONE" "Interview_By_Telephone", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_VIDEO_CALL" "Interview_By_Video_Call", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_WITH_ATTNDENT" "Interview_With_Attendant", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_OTHER" "Interview_Other", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL" "Employment_Goal", "WBC_LATEST_ES_OES_APP_D"."HOURS_PER_WEEK" "Hours_per_Week_Goal", "WBC_LATEST_ES_OES_APP_D"."WAGE_PER_HOUR" "Wage_Per_Hour_Goal", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_SEASONAL" "Goal_is_Seasonal", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_CASUAL" "Goal_is_Casual", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_RELOCATE" "Can_Relocate", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_TRANSPORT" "Has_Transportation", "WBC_LATEST_ES_OES_APP_D"."PORTAL_APPLICATION_NUMBER" "OES_Application_Num", "WBC_LATEST_ES_OES_APP_D"."OFFICE" "Office", "WBC_LATEST_ES_OES_APP_D"."ORGANIZATION" "Contractor_Name", "WBC_LATEST_ES_OES_APP_D"."CATCHMENT" "Catchment_Selected"
 from "CDW"."WBC_CASE_D" "WBC_CASE_D", "CDW"."WBC_DATE_D" "WBC_DATE_D_Start", "CDW"."WBC_ES_STAGE_OF_SERVICE_D" "WBC_ES_STAGE_OF_SERVICE_D", "CDW"."WBC_CASE_F" "coguda30", "CDW"."WBC_OFFICE_D" "coguda31", "CDW"."WBC_LATEST_ES_OES_APP_D" "WBC_LATEST_ES_OES_APP_D"
 where "coguda30"."OFFICE_ORG_WID"="coguda31"."OFFICE_ORG_WID" and "coguda30"."CASE_TYPE_WID"=1 and "coguda30"."SNAPSHOT_DT_WID"=(
select snapshot_dt_wid
 from cdw.wbc_run_ctl_d) and "coguda30"."CASE_WID"="WBC_CASE_D"."CASE_WID" and "coguda30"."ES_STAGE_OF_SERVICE_WID"="WBC_ES_STAGE_OF_SERVICE_D"."ES_STAGE_OF_SERVICE_WID" and "WBC_DATE_D_Start"."DATE_WID"="coguda30"."PLAN_START_DT_WID" and "coguda30"."TAAAPA_WID"="WBC_LATEST_ES_OES_APP_D"."TAAAPA_WID"
 group by "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_EMPLOYED", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_PRECARIOUSLY_EMPLOYED", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_SELF_EMPLOYED", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_UNEMPLOYED", "WBC_LATEST_ES_OES_APP_D"."ACCEPTED_NOT_IN_LABOUR_FORCE", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_IN_PERSON", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_PHONE", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_VIDEO_CALL", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_WITH_ATTNDENT", "WBC_LATEST_ES_OES_APP_D"."INTERVIEW_METHOD_OTHER", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL", "WBC_LATEST_ES_OES_APP_D"."HOURS_PER_WEEK", "WBC_LATEST_ES_OES_APP_D"."WAGE_PER_HOUR", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_SEASONAL", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_CASUAL", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_RELOCATE", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_GOAL_TRANSPORT", "WBC_LATEST_ES_OES_APP_D"."PORTAL_APPLICATION_NUMBER", "WBC_LATEST_ES_OES_APP_D"."OFFICE", "WBC_LATEST_ES_OES_APP_D"."ORGANIZATION", "WBC_LATEST_ES_OES_APP_D"."CATCHMENT", "WBC_LATEST_ES_OES_APP_D"."EMPLOYED", "WBC_LATEST_ES_OES_APP_D"."UNEMP_PERSONAL_SITUATION", "WBC_LATEST_ES_OES_APP_D"."UNEMP_KEEPING_JOBS", "WBC_LATEST_ES_OES_APP_D"."UNEMP_DISABLTY_SUPPORTS_NEEDED", "WBC_LATEST_ES_OES_APP_D"."UNEMP_KIND_OF_WORK_UNKNOWN", "WBC_LATEST_ES_OES_APP_D"."UNEMP_FNCL_SUPPORTS_NEEDED", "WBC_LATEST_ES_OES_APP_D"."UNEMP_TRAINING_NEEDED", "WBC_LATEST_ES_OES_APP_D"."UNEMP_JOB_SEARCH_HELP_NEEDED", "WBC_LATEST_ES_OES_APP_D"."UNEMP_JOB_OFFER_LACK_RESOURCES", "WBC_LATEST_ES_OES_APP_D"."UNEMP_RETURN_TO_SAME_WORK", "WBC_LATEST_ES_OES_APP_D"."UNEMP_OTHER_FACTOR", "WBC_LATEST_ES_OES_APP_D"."EMP_SELF_EMPLOYED", "WBC_LATEST_ES_OES_APP_D"."EMP_LOSING_JOB", "WBC_LATEST_ES_OES_APP_D"."EMP_DISABLTY_SUPPORTS_NEEDED", "WBC_LATEST_ES_OES_APP_D"."EMP_JOB_OFFER_LACK_RESOURCES", "WBC_LATEST_ES_OES_APP_D"."EMP_NEED_MORE_HOURS_OF_WORK", "WBC_LATEST_ES_OES_APP_D"."EMP_TRAINING_NEEDED", "WBC_LATEST_ES_OES_APP_D"."EMP_NEW_LINE_OF_WORK", "WBC_LATEST_ES_OES_APP_D"."EMP_SEEKEING_CHANGE", "WBC_LATEST_ES_OES_APP_D"."EMP_CHALLENGING_JOB", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_OTHER", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_SITUATION_LIST", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_AGE", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_LACK_HOUSING", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_ADDICTION", "WBC_LATEST_ES_OES_APP_D"."VISIBLE_MINORITY", "WBC_LATEST_ES_OES_APP_D"."CHILDREN_AT_HOME", "WBC_LATEST_ES_OES_APP_D"."SINGLE_PARENT", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_PHYSICAL", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_LEARNING", "WBC_LATEST_ES_OES_APP_D"."DEVELOPMENTAL_DISABILITY", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_VISUAL", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_HEARING", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_MENTAL_HEALTH", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_CHRONIC_ILLNESS", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_SHORT_TERM_ILLNESS", "WBC_LATEST_ES_OES_APP_D"."DISABILITY_OTHER", "WBC_LATEST_ES_OES_APP_D"."EMPLOYMENT_FACTOR_LIST", "WBC_LATEST_ES_OES_APP_D"."MARITAL_STATUS", "WBC_LATEST_ES_OES_APP_D"."TOTAL_DEPENDENTS", "WBC_LATEST_ES_OES_APP_D"."SCHOOL_LEVEL", "WBC_LATEST_ES_OES_APP_D"."CURRENTLY_IN_SCHOOL", "WBC_LATEST_ES_OES_APP_D"."CURRENTLY_IN_SCHOOL_STATUS", "WBC_LATEST_ES_OES_APP_D"."AREA_OF_STUDY", "WBC_LATEST_ES_OES_APP_D"."INDIGENOUS_TYPE", "WBC_LATEST_ES_OES_APP_D"."STATUS_INDIAN", "WBC_LATEST_ES_OES_APP_D"."IMMIGRATION_DATE", "WBC_LATEST_ES_OES_APP_D"."REFUGEE_TYPE", "WBC_LATEST_ES_OES_APP_D"."CITIZENSHIP_STATUS", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_EMPLOYER", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_JOB_TITLE", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_INDUSTRY", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_START_DATE", "WBC_LATEST_ES_OES_APP_D"."MOST_RECENT_WORK_END_DATE", "WBC_LATEST_ES_OES_APP_D"."REASON_FOR_LEAVING_EMPLOYMENT", "WBC_LATEST_ES_OES_APP_D"."EXPLAINING_TO_OTHERS", "WBC_LATEST_ES_OES_APP_D"."GET_ALONG_WITH_OTHERS", "WBC_LATEST_ES_OES_APP_D"."LEARNING_NEW_THINGS", "WBC_LATEST_ES_OES_APP_D"."ORGANIZING_INFORMATION", "WBC_LATEST_ES_OES_APP_D"."PROBLEM_SOLVING", "WBC_LATEST_ES_OES_APP_D"."READING_INFORMATION", "WBC_LATEST_ES_OES_APP_D"."USING_COMPUTERS", "WBC_LATEST_ES_OES_APP_D"."CREATING_DOCUMENTS", "WBC_LATEST_ES_OES_APP_D"."WORKING_WITH_MATH", "WBC_LATEST_ES_OES_APP_D"."WRITING_INFORMATION", "WBC_CASE_D"."CASE_NUM", "WBC_DATE_D_Start"."CALENDAR_DATE", "WBC_ES_STAGE_OF_SERVICE_D"."STAGE_OF_SERVICE_NAME"


"""

df = pd.read_sql(query, con=conn)
print(df.head)
# Out:
# <bound method NDFrame.head of             Case_Number Start_Date1             Stage_of_Employment_Service  \
# 0       1-421153-103722  2013-10-03      Left Before Completing Sustainment
# 1       1-421153-103862  2013-10-07  Before Sustainable Employment Achieved
# 2       1-421153-140157  2019-01-17       Left After Completing Sustainment
# 3       1-421153-141452  2021-03-25  Before Sustainable Employment Achieved
# 4       1-421153-141552  2013-10-30       Left After Completing Sustainment
# ...                 ...         ...                                     ...
# 116625    1-65395753413  2021-09-29  Before Sustainable Employment Achieved
# 116626    1-65444758760  2021-10-04  Before Sustainable Employment Achieved
# 116627    1-58629048361  2021-10-04  Before Sustainable Employment Achieved
# 116628    1-65460472689  2021-10-05  Before Sustainable Employment Achieved
# 116629    1-65464863270  2021-10-05  Before Sustainable Employment Achieved
#
# ...

# %%
t = df.columns.to_frame()
t.to_csv('df_columns.csv')
